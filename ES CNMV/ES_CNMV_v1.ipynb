# %%
# %%

#------------------------------------------------ Begin_Librairie ----------------------------------------

import datetime

import pandas as pd

from pandas import ExcelWriter

from selenium import webdriver

import math

import time

from time import sleep

import os

from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.support.ui import Select

from selenium.webdriver.support import expected_conditions

from webdriver_manager.chrome import ChromeDriverManager

# %%

# %%
# %%

#------------------------------------------------ Begin_ fileName ----------------------------------------

regulatorName = 'ES CNMV' ## change to current controller name



print(f"Running {regulatorName} Web Scraping Tool v.1.3")

now=datetime.datetime.now()

filename = '{} SQL Ready {}.xlsx'.format(regulatorName, str(now).replace(":",".")[:-7])

scriptfolder = f"C:\\Users\\wuj1\\OneDrive - moodys.com\\Desktop\\Regulator\\{regulatorName}"
#scriptfolder=os.path.dirname(os.path.abspath(__file__)) ## to decomment for the production environment

os.chdir(scriptfolder)

writer = ExcelWriter(filename, engine='openpyxl')

tempfolder=os.path.join(scriptfolder, 'tempfolder') #if files are downloaded during the process



if os.path.exists(tempfolder):

    for rem in os.listdir(tempfolder):

        os.remove(os.path.join(tempfolder, rem))

else:

    os.mkdir(tempfolder)
# Out:
# Running ES CNMV Web Scraping Tool v.1.3

# %%
# %%

#------------------------------------------------ Begin_chromedriver ----------------------------------------

#Starting Chrome driver, set to download files in tempfolder

chromeOptions = webdriver.ChromeOptions()

prefs = {"plugins.always_open_pdf_externally": True,

		 "download.prompt_for_download": False,

		 "download.default_directory" : tempfolder}

chromeOptions.add_experimental_option("prefs",prefs)

driver = webdriver.Chrome(options=chromeOptions)

driver.maximize_window()




# %%

# %%
# %%

#------------------------------------------------ Begin_Variable ----------------------------------------

regdict={

        'ES CNMV 1': 'https://www.cnmv.es/Portal/Consultas/ListadoEntidad.aspx?id=2&tipoent=0',
        'ES CNMV 2': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=6',
        'ES CNMV 3': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=26',
        'ES CNMV 4': 'https://www.cnmv.es/Portal/Consultas/ListadoEntidad.aspx?id=3',
        'ES CNMV 5': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=5',
        'ES CNMV 6': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=3',
        'ES CNMV 7': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=7',
        'ES CNMV 8': 'https://www.cnmv.es/Portal/Consultas/listadoentidad.aspx?id=1&tipoent=10',
        'ES CNMV 9': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=19',
        'ES CNMV 10': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=20',
        'ES CNMV 11': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=1&tipoent=2',
        'ES CNMV 12': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=1&tipoent=0',
        'ES CNMV 13': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=1&tipoent=13',
        'ES CNMV 14': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=1&tipoent=7',
        'ES CNMV 15': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=1&tipoent=8',
        'ES CNMV 16': 'https://www.cnmv.es/Portal/Consultas/ListadoEntidad.aspx?id=2&tipoent=1',
        'ES CNMV 17': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=21',
        'ES CNMV 18': 'https://www.cnmv.es/Portal/Consultas/ListadoEntidad.aspx?id=2&tipoent=3',
        'ES CNMV 19': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=22',
        'ES CNMV 20': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=23',
        'ES CNMV 21': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=24',
        'ES CNMV 22': 'https://www.cnmv.es/Portal/consultas/listadoentidad.aspx?id=4&tipoent=0',
        'ES CNMV 23': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=0',
        'ES CNMV 24': 'https://www.cnmv.es/Portal/consultas/mostrarlistados.aspx?id=1',
        'ES CNMV 25': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=17',
        'ES CNMV 26': 'https://www.cnmv.es/Portal/Consultas/MostrarListados.aspx?id=18',
        'ES CNMV 27': 'https://www.cnmv.es/portal/Consultas/MostrarListados.aspx?id=8',

        }



Typology={

'ES CNMV 1':    'Collective investment scheme management companies',
'ES CNMV 2':	'Collective investment schemes of free investment schemes (IICIICIL)',
'ES CNMV 3':	'Complete list of UCITS',
'ES CNMV 4':	'Depositary companies',
'ES CNMV 5':	'Free investment schemes (FIL and SIL)',
'ES CNMV 6':	'Harmonized financial investment funds',
'ES CNMV 7':	'Harmonized investment companies',
'ES CNMV 8':	'List of Banks that are subsidiaries of Community credit companies operating in Spain under free provision',
'ES CNMV 9':	'List of European Venture Capital Companies – Small and Mid Caps',
'ES CNMV 10':	'List of European Venture Capital Funds - Small and Mid Caps',
'ES CNMV 11':	'List of Financial Advisory Firms',
'ES CNMV 12':	'List of Investment Firms (Portfolio Management excluded)',
'ES CNMV 13':	'List of National Financial Advisory Companies',
'ES CNMV 14':	'List of Spanish Credit Institutions',
'ES CNMV 15':	'List of branches of European Economic Area Credit Institutions',
'ES CNMV 16':	'List of branches of european economic area management companies',
'ES CNMV 17':	'List of european capital risk entities',
'ES CNMV 18':	'List of european economic area management companies under the freedom of providing services',
'ES CNMV 19':	'List of european social entrepreneurship funds',
'ES CNMV 20':	'List of investment company of closed type',
'ES CNMV 21':	'List of investment fund closed type',
'ES CNMV 22':	'List of management companies of venture capital entities',
'ES CNMV 23':	'List of venture capital companies',
'ES CNMV 24':	'List of venture capital funds',
'ES CNMV 25':	'Non-harmonized financial investment funds',
'ES CNMV 26':	'Non-harmonized investment companies',
'ES CNMV 27':	'Real estate investment companies (SII)'

        }



sqldict={'bvdid': [], 'priority': [], 'ListLabel': [], 'Typology': [], 'EntryType': [], 'Name': [], 'InternalID_1': [], 'InternalID_1_type': [], 'InternalID_2': [], 

          'InternalID_2_type': [], 'InternalID_3': [], 'InternalID_3_type': [], 'CoType': [], 'License_Type': [], 'Address_1': [], 'Address_2': [], 'City': [], 

          'Zip': [], 'Cntry': [], 'Phone': [], 'Fax': [], 'Website': [], 'Email': [], 'RegulationType': [], 'RegulationTypeCode': [], 'RegulationDate': [], 'CancellationDate': [], 

          'RegCtry': [], 'RegCode' : [], 'ListCode': [], 'ListLanguage': [], 'ListValidityDate': [], 'ListName': [], 'ListProcessDate': [],
        }


now = datetime.datetime.now()

processdate = now.strftime('%Y-%m-%d')

# %%
# %%

#------------------------------------------------ Begin_Fouction ----------------------------------------

def bourange_same_length_array(sqldict) :

    maxlen = len(sqldict['ListProcessDate'])

    for key, val in sqldict.items():

        if len(sqldict[key]) != maxlen:

            empty = []

            total_empty = maxlen - len(sqldict[key])

            for i in range(total_empty):

                empty.append('')

            sqldict[key]=sqldict[key]+empty

    return sqldict



# Define a function to scroll to the bottom of the page

def scroll_to_bottom(driver):

    # Get scroll height

    last_height = driver.execute_script("return document.body.scrollHeight")



    while True:

        # Scroll down to the bottom

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        # Wait to load the page

        sleep(3)
        # Calculate new scroll height and compare with last scroll height

        new_height = driver.execute_script("return document.body.scrollHeight")

        if new_height == last_height:

            break

        last_height = new_height

def click_element_by_xpath(driver, xpath):

    # Find the element and click

    element = driver.find_element(By.XPATH, xpath)

    element.click()
    

def click_on_cookies(web_driver):

    try:

        web_driver.find_element(By.XPATH,f'//*[@id="modal-content-id-1"]/footer/div/button[3]').click()
        print('[Success] : Success to Click Cookie')

    except Exception as err:

        print('[ERROR] : Failed to click "I Accept" button on the cookies banner:', err)
        

def scrollinAndClick(xpath,key_press=False):
    if len(xpath) != 0 :
        for times in range(60):
            try:
                driver.find_element(By.XPATH, xpath).click()
                sleep(1)
                break
            except:
                print(f"[ERROR] : trying {times+1}/10 to key press 'DOWN' (scrolling)")
                sleep(1)
                if key_press:                    
                    driver.find_element(By.TAG_NAME, 'body').send_keys(key_press)
        else:   
            raise Exception(f'[ERROR] : Failed scrollin Or Click on xpath element : {xpath}')

def check_dowload_files(tempfolder, fileType, wait_time=10):

    for time in range(wait_time):

        if len([ele for ele in os.listdir(tempfolder) if '.crdownload' not in ele and '.tmp' not in ele]) != 0 :

            print(f"[INFO] : - {fileType} file = {os.listdir(tempfolder)[0]}")

            break

        else:

            print(f"[INFO] : - Download {fileType} file ... (wait {time*2}/{wait_time*2} s)")

            sleep(2)

    else:

        raise Exception(f'[ERROR] : - Failed to Download {fileType} file. Run Script again' )

# %%
# %%

#------------------------------------------------ Begin_Main ----------------------------------------

for k, reg in enumerate(regdict):
    # if k <=13:
    #     continue

    print(f"[INFO] : Working {k+1}/{len(regdict)} _({reg})_ ")

   
    driver.get(regdict[reg])    

    hasPage = False
    # while not hasPage:
    sleep(3)
    soup=BeautifulSoup(driver.page_source, 'html.parser')
    sleep(3)
    
    if k == 0 or k ==1 or  k == 3 or k ==10 or k==11 or k==12 or k==15 or k==17 or k==21 or k==26:
        ul = soup.find('ul',id = 'listaElementosPrimernivel')
        lis = ul.find_all('li')
        print(len(lis))
        for li in lis:
            info_list = li.find_all('li')
            if (len(info_list))>0:
                
                name = info_list[0].text.strip()
                sqldict['Name'].append(name)
                sqldict['ListProcessDate'].append(processdate)
                
                
                register_number = info_list[1].text.strip()
                internal_number = register_number.split(':')[1].split('-')[0]
                date_regulated = register_number.split(':')[1].split('-')[1]
                sqldict['InternalID_1'].append(internal_number) 
                sqldict['InternalID_1_type'].append('Official registration number')
                
                sqldict['RegulationDate'].append(date_regulated) 
                if k == 17 or k==1:
                    sqldict['Zip'].append('')
                    sqldict['City'].append('')
                    sqldict['Address_1'].append('')
                    sqldict['Cntry'].append('') 
                    
                elif k != 17 or k!=1:
                    address =  info_list[2].text.strip()
                    detailed_address = address.split(':')[1]
                    sqldict['Address_1'].append(detailed_address)
                
                    try:
                        country=info_list[3].text.strip().split(':')[1]
                        sqldict['Cntry'].append(country) 
                    except:
                        sqldict['Cntry'].append(' ') 
                    
                    try:
                        zip_code = detailed_address.split('-')[-1].split(' ')[1]
                        sqldict['Zip'].append(zip_code)
                        city = detailed_address.split('-')[-1].split(' ')[2:]
                        print(f'City: -- {city}')
                        city_info = ''
                        for c in city:
                            city_info+=c +' '
                            
                        print(f'CityInfo: -- {city_info}')
                        sqldict['City'].append(city_info)
                    
                    except:
                        sqldict['City'].append('')
                        sqldict['Zip'].append('')
                        print('No country infomation')

                sqldict['RegCtry'].append(reg.split(' ')[0]) 
                sqldict['RegCode'].append(reg.split(' ')[1])
                sqldict['ListCode'].append(reg.split(' ')[-1])
                sqldict['ListName'].append(Typology[reg])
                sqldict['RegulationType'].append('Regulated')
        sqldict = bourange_same_length_array(sqldict)
        
            
        # for li in lis:
            
        #     print(li.text)
    
    if k == 2 or k == 4 or k ==5 or k==6 or k==8 or k == 9 or k ==16 or k==18 or k==19 or k==20 or k==22 or k==23 or k==24 or k==25:
        sleep(3)
        scroll_to_bottom(driver)
        sleep(3)
        if soup.find('ul',class_='pagination'):
            hasPage = True
            total_page = soup.find('span',class_='PagActivaTXT').text.split(' ')[-1]
            print(total_page)
        while hasPage:
            for pageNum in range(0,int(total_page)):
                link = regdict[reg]+'&page='+str(pageNum)
                driver.get(link)
                sleep(3)
                soup=BeautifulSoup(driver.page_source, 'html.parser')
                sleep(3)
                ul = soup.find('ul',id = 'listaElementosPrimernivel')
                lis = ul.find_all('li')
                print(len(lis))

                ## Test 
                if pageNum>=5:
                    break
                for li in lis:
                    info_list = li.find_all('li')
                    if (len(info_list))>0:
                        
                        name = info_list[0].text.strip()
                        print(name)
                        sqldict['Name'].append(name)
                        sqldict['ListProcessDate'].append(processdate)
                        
                        
                        register_number = info_list[1].text.strip()
                        
                        internal_number = register_number.split(':')[1].split('-')[0]
                        date_regulated = register_number.split(':')[1].split('-')[1]
                        sqldict['InternalID_1'].append(internal_number) 
                        sqldict['InternalID_1_type'].append('Official registration number')
                        #print(internal_number)
                        #print(date_regulated)
                        sqldict['RegulationDate'].append(date_regulated) 
                        if k==4 or k==5 or k==9 or k==16 or k==18 or k==20 or k==23 or k==24:
                            sqldict['Zip'].append('')
                            sqldict['City'].append('')
                            sqldict['Address_1'].append('')
                            sqldict['Cntry'].append('') 
                            
                        elif k!=4 or k!=5 or k!=9 or k!=16 or k!=18 or k!=20 or k!=23 or k!=24:
                            try:
                                address =  info_list[2].text.strip()
                                detailed_address = address.split(':')[1]
                                sqldict['Address_1'].append(detailed_address)
                                zip_code = detailed_address.split('-')[-1].split(' ')[1]
                                sqldict['Zip'].append(zip_code)
                                city = detailed_address.split('-')[-1].split(' ')[2:]
                                if len(city)>1:
                                    city_info = ''
                                    for c in city:
                                        city_info+=c +' '
                                    sqldict['City'].append(city_info)
                                else:
                                    sqldict['City'].append(detailed_address.split('-')[-1].split(' ')[2])
                                

                            except:
                                print('Maybe no address information, please check the website')
                                # sqldict['Address_1'].append('')
                                # sqldict['City'].append('')
                                # sqldict['Zip'].append('')
                            

                        sqldict['RegCtry'].append(reg.split(' ')[0]) 
                        sqldict['RegCode'].append(reg.split(' ')[1])
                        sqldict['ListCode'].append(reg.split(' ')[-1])
                        sqldict['ListName'].append(Typology[reg])
                        sqldict['RegulationType'].append('Regulated')
                    sqldict = bourange_same_length_array(sqldict)
            hasPage = False
            sqldict = bourange_same_length_array(sqldict)
    if k == 7:
        sleep(3)
        ul = soup.find('ul',id = 'listaElementosPrimernivel')
        sleep(3)
        lis = ul.find_all('li')
        print(len(lis))
        for li in lis:
            info_list = li.find_all('li')
            if (len(info_list))>0:
                
                name = info_list[0].text.strip()
                sqldict['Name'].append(name)
                sqldict['ListProcessDate'].append(processdate)

                
                register_number = info_list[1].text.strip()
                internal_number = register_number.split(':')[1]
                sqldict['InternalID_1'].append(internal_number) 
                sqldict['InternalID_1_type'].append('Official registration number')
                
                country = info_list[2].text.strip().split(':')[1]
                sqldict['Cntry'].append(country) 
                
                sqldict['RegCtry'].append(reg.split(' ')[0]) 
                sqldict['RegCode'].append(reg.split(' ')[1])
                sqldict['ListCode'].append(reg.split(' ')[-1])
                sqldict['ListName'].append(Typology[reg])
                sqldict['RegulationType'].append('Regulated')
        sqldict = bourange_same_length_array(sqldict)
    if k == 13 or k==14:
        ul = soup.find('ul',id = 'listaElementosPrimernivel')
        sleep(3)
        lis = ul.find_all('li')
        print(len(lis))
        for li in lis:
            info_list = li.find_all('li')
            if (len(info_list))>0:
                
                name = info_list[0].text.strip()
                sqldict['Name'].append(name)
                sqldict['ListProcessDate'].append(processdate)
                
                register_number = info_list[1].text.strip()
                if (k ==14):
                    internal_number = register_number.split(':')[1]
                else:
                    internal_number = register_number.split(':')[1].split('-')[0]
                    sqldict['RegulationDate'].append('') 
                    
                sqldict['InternalID_1'].append(internal_number) 
                sqldict['InternalID_1_type'].append('Bank of Spain Code')
                
                address =  info_list[2].text.strip()
                detailed_address = address.split(':')[1]
                sqldict['Address_1'].append(detailed_address)
                
                city = detailed_address.split('-')[-1].split(' ')[2:]
                
                zip_code = detailed_address.split('-')[-1].split(' ')[1]
                sqldict['Zip'].append(zip_code)
                
                if len(city)>1:
                    city_info = ''
                    for c in city:
                        city_info+=c +' '
                    sqldict['City'].append(city_info)
                else:
                    sqldict['City'].append(city[0])
                
                # city_info = ''
                # for c in city:
                #     city_info+=c +' '
                # sqldict['City'].append(city_info)
                


                sqldict['RegCtry'].append(reg.split(' ')[0]) 
                sqldict['RegCode'].append(reg.split(' ')[1])
                sqldict['ListCode'].append(reg.split(' ')[-1])
                sqldict['ListName'].append(Typology[reg])
                sqldict['RegulationType'].append('Regulated')
        sqldict = bourange_same_length_array(sqldict)
    # if k>=1:
    #     break           

                


sqldict = bourange_same_length_array(sqldict)
# Out:
# [INFO] : Working 1/27 _(ES CNMV 1)_
# 595
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['Madrid']
# CityInfo: -- Madrid
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['BILBAO']
# CityInfo: -- BILBAO
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['Madrid']
# CityInfo: -- Madrid
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['BILBAO']
# CityInfo: -- BILBAO
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# CityInfo: -- MADRID
# City: -- ['MADRID']
# ...

# %%
# %%

#------------------------------------------------ Begin_writer and save df to excel  ----------------------------------------


os.chdir(scriptfolder)

df=pd.DataFrame(sqldict)

df  = df.drop_duplicates()

df.to_excel(writer, 'SQL Ready', index=False)

writer.save()

writer.close()

driver.quit()

sleep(3)
# Out:
# C:\Users\wuj1\AppData\Local\Temp\1\ipykernel_13912\2773079153.py:12: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   df.to_excel(writer, 'SQL Ready', index=False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 14
#      10 df  = df.drop_duplicates()
#      12 df.to_excel(writer, 'SQL Ready', index=False)
# ---> 14 writer.save()
#      16 writer.close()
#      18 driver.quit()
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'

# %%
# check which is different

key_value_counts = {key: len(values) for key, values in sqldict.items()}

# Print the counts
for key, count in key_value_counts.items():
    
    print(f"Key '{key}' has {count} values.")
# Out:
# Key 'bvdid' has 2008 values.
# Key 'priority' has 2008 values.
# Key 'ListLabel' has 2008 values.
# Key 'Typology' has 2008 values.
# Key 'EntryType' has 2008 values.
# Key 'Name' has 2008 values.
# Key 'InternalID_1' has 2008 values.
# Key 'InternalID_1_type' has 2008 values.
# Key 'InternalID_2' has 2008 values.
# Key 'InternalID_2_type' has 2008 values.
# Key 'InternalID_3' has 2008 values.
# Key 'InternalID_3_type' has 2008 values.
# Key 'CoType' has 2008 values.
# Key 'License_Type' has 2008 values.
# Key 'Address_1' has 2008 values.
# Key 'Address_2' has 2008 values.
# Key 'City' has 2008 values.
# Key 'Zip' has 2008 values.
# Key 'Cntry' has 2008 values.
# Key 'Phone' has 2008 values.
# Key 'Fax' has 2008 values.
# Key 'Website' has 2008 values.
# Key 'Email' has 2008 values.
# Key 'RegulationType' has 2008 values.
# Key 'RegulationTypeCode' has 2008 values.
# Key 'RegulationDate' has 2008 values.
# Key 'CancellationDate' has 2008 values.
# Key 'RegCtry' has 2008 values.
# ...

# %%
df.to_csv('list0to5.csv')

# %%
regdict['ES CNMV 3']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 regdict[2]== 'ES CNMV 3'
#
# KeyError: 2

# %%
df.to_csv('list_3.csv')
